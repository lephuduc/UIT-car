# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
import numpy as np 
import os
import skimage.io as io
import skimage.transform as trans
import numpy as np
import tensorflow
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as keras
import PIL

# %%
def unet(pretrained_weights = None,input_size = (80,160,3)):
    inputs = Input(input_size)
    conv1 = Conv2D(8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = Conv2D(8, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(8, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    # conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv10)

   
    
    #model.summary()


    return model

# %%
model=unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 80, 160, 3)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 80, 160, 8)   224         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 80, 160, 8)   584         ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 40, 80, 8)    0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 40, 80, 16)   1168        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 40, 80, 16)   2320        ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 20, 40, 16)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 20, 40, 32)   4640        ['max_pooling2d_1[0][0]']
#
# ...

# %%
import pickle
train_images=pickle.load(open("full_CNN_train.p","rb"))
label_images=pickle.load(open("full_CNN_labels.p","rb"))

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(np.array(train_images[0]))

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(np.array(label_images[0]).reshape(80,160))

# %%
train_images=np.array(train_images)
label_images=np.array(label_images)
print(np.max(label_images))
print(np.min(label_images))
print(np.histogram(label_images))
# Out:
# 255
# 0
# (array([136891982,    308182,    249712,    206780,    205082,    196602,
#           216766,    283570,    373568,  24446956]), array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#        229.5, 255. ]))

# %%
label_images=np.where(label_images<127,0,255)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(np.array(label_images[0]).reshape(80,160))

# %%
label_images=label_images/255.0

# %%
from tensorflow.keras.metrics import MeanIoU
class MyMeanIoU(MeanIoU):
  def update_state(self, y_true, y_pred, sample_weight=None):
    return super().update_state(y_true, tensorflow.where(y_pred<0.5,0,1), sample_weight)
model.compile(optimizer = Adam(lr = 1e-3), loss = 'binary_crossentropy', metrics = [MyMeanIoU(num_classes=2)])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen=ImageDataGenerator(brightness_range=[0.8,1.2])
from keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',patience=3,verbose=1,factor=0.5,min_lr=1e-6)
checkpoint= ModelCheckpoint('models/model-{epoch:03d}.h5',monitor='val_loss',verbose=1,save_best_only=True,mode='auto')
callb=[checkpoint,learning_rate_reduction]

# %%
# %cd train1
# !mkdir models
# Out:
# /content/drive/My Drive/Colab Notebooks/train1
# mkdir: cannot create directory ‘models’: File exists

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train_images, label_images, test_size=0.2, random_state=42)

# %%
history=model.fit(datagen.flow(X_train, y_train, batch_size=32), steps_per_epoch=len(X_train)/32,
    epochs=40, verbose=1, validation_data=(X_val, y_val),callbacks=callb)
# Out:
# Epoch 1/40
# 320/319 [==============================] - ETA: 0s - loss: 0.4477 - my_mean_io_u: 0.7338
# Epoch 00001: val_loss improved from inf to 0.07670, saving model to models/model-001.h5
# 319/319 [==============================] - 72s 148ms/step - loss: 0.4477 - my_mean_io_u: 0.7338 - val_loss: 0.0767 - val_my_mean_io_u: 0.8940 - lr: 0.0010
# Epoch 2/40
# 320/319 [==============================] - ETA: 0s - loss: 0.0491 - my_mean_io_u: 0.9333
# Epoch 00002: val_loss improved from 0.07670 to 0.06424, saving model to models/model-002.h5
# 319/319 [==============================] - 45s 142ms/step - loss: 0.0491 - my_mean_io_u: 0.9333 - val_loss: 0.0642 - val_my_mean_io_u: 0.9010 - lr: 0.0010
# Epoch 3/40
# 320/319 [==============================] - ETA: 0s - loss: 0.0357 - my_mean_io_u: 0.9485
# Epoch 00003: val_loss improved from 0.06424 to 0.03843, saving model to models/model-003.h5
# ...

# %%
plt.imshow(np.array(y_val[0].reshape(80,100)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-de134f08fff8> in <module>()
# ----> 1 plt.imshow(np.array(y_val[0].reshape(80,100)))
#
# ValueError: cannot reshape array of size 12800 into shape (80,100)
